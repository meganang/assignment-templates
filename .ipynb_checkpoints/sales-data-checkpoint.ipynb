# %%
import pandas as pd

fct_df = pd.read_csv("fct_invoice.csv")

fct_df
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 8 columns]

# %%
#Easy #1: How many unique customers are in the dataset?

print("There are", len(fct_df['customer_id'].unique()), "unique customers in the dataset.")
# Out:
# There are 5191 unique customers in the dataset.

# %%
#Easy #2: What are the different categories of products available? How many unique categories are there?

print("The different categories of products are", fct_df['category'].unique(), ". There are", len(fct_df['category'].unique()), "unique categories.")
# Out:
# The different categories of products are ['Clothing' 'Shoes' 'Books' 'Cosmetics' 'Food & Beverage' 'Toys'
#  'Technology' 'Souvenir'] . There are 8 unique categories.

# %%
#Easy #3: Which payment method is the most popular? How many times was it used?

dct = dict(fct_df['payment_method'].value_counts())
most_popu = list(dct.keys())

print("The most popular payment method is", most_popu[0], "which was used", dct[most_popu[0]], "times.")
# Out:
# The most popular payment method is Cash which was used 44447 times.

# %%
#Medium #1: What are the three most popular categories, by total sales?

fct_df['total_sales'] = fct_df['quantity']*fct_df['price']

fct_df.groupby(['category']).sum()['total_sales'].head(3)
# Out:
# C:\Users\megan\AppData\Local\Temp\ipykernel_16468\3438893262.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fct_df.groupby(['category']).sum()['total_sales'].head(3)
# category
# Books        8.345529e+05
# Clothing     1.139968e+08
# Cosmetics    6.792863e+06
# Name: total_sales, dtype: float64

# %%
json_df = pd.read_json("dim_customer.json")
json_df
# Out:
#        age first_name gender     id last_name
# 0     48.0   Nicholas      M      0    Flores
# 1      NaN    Jeffery      M      1      Rowe
# 2     57.0     Alexis      F      2    Benton
# 3     73.0        Amy      F      3   Johnson
# 4     20.0      David      M      4     Moore
# ...    ...        ...    ...    ...       ...
# 5186   NaN     Arthur      M   9428    Harris
# 5187   NaN      David      M   9494       Roy
# 5188  85.0     Thomas      M  10350    Turner
# 5189   NaN      April      F  10587   Sanchez
# 5190   NaN     Andrew      M  10934   Compton
#
# [5191 rows x 5 columns]

# %%
df3 = pd.merge(fct_df, json_df, left_on = "customer_id", right_on = "id")

df3
# Out:
#       invoice_no  customer_id   category  quantity    price payment_method  \
# 0        I138884          229   Clothing         5  1500.40    Credit Card
# 1        I126377          229  Cosmetics         2    81.32    Credit Card
# 2        I178419          229      Shoes         3  1800.51     Debit Card
# 3        I847727          229   Clothing         3   900.24    Credit Card
# 4        I219251          229      Shoes         5  3000.85    Credit Card
# ...          ...          ...        ...       ...      ...            ...
# 99452    I198027         4973      Shoes         1   600.17           Cash
# 99453    I989120         6161      Books         5    75.75           Cash
# 99454    I791963         6779   Clothing         5  1500.40    Credit Card
# 99455    I100582         8386   Clothing         2   600.16           Cash
# 99456    I934204         4761  Cosmetics         4   162.64           Cash
#
#       invoice_date   shopping_mall  total_sales   age first_name gender    id  \
# 0         5/8/2022          Kanyon      7502.00   NaN    William      M   229
# 1         5/4/2021       Metrocity       162.64   NaN    William      M   229
# 2         1/6/2021    Istinye Park      5401.53   NaN    William      M   229
# 3       21/08/2022    Zorlu Center      2700.72   NaN    William      M   229
# 4       23/06/2022    Istinye Park     15004.25   NaN    William      M   229
# ...            ...             ...          ...   ...        ...    ...   ...
# 99452    8/11/2021          Kanyon       600.17   NaN    Melissa      F  4973
# 99453     8/1/2021  Viaport Outlet       378.75  36.0     Leslie      F  6161
# 99454     6/3/2021    Metropol AVM      7502.00   NaN      Kelly      F  6779
# 99455    2/11/2021    Istinye Park      1200.32  47.0      Shawn      M  8386
# 99456   31/08/2022  Forum Istanbul       650.56  52.0     Ashley      F  4761
#
#       last_name
# 0      Anderson
# 1      Anderson
# 2      Anderson
# 3      Anderson
# 4      Anderson
# ...         ...
# 99452      Bell
# 99453      Bass
# 99454   Roberts
# 99455     Perez
# 99456   Jackson
#
# [99457 rows x 14 columns]

# %%
#Medium #2: What are the total sales attributed to customers over the age of 45?

df3.groupby(['age']).sum()['total_sales']

dct = dict(df3.groupby(['age']).sum()['total_sales'])

ages = list(dct.keys())

sales_sum = 0 

for age in range(len(ages)):
    if ages[age] > 45:
        sales_sum = sales_sum + dct[ages[age]]

print("The total sales attributed to customers over the age of 45 is", sales_sum)
# Out:
# The total sales attributed to customers over the age of 45 is 82039768.15
# C:\Users\megan\AppData\Local\Temp\ipykernel_16468\3003995093.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby(['age']).sum()['total_sales']
# C:\Users\megan\AppData\Local\Temp\ipykernel_16468\3003995093.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dct = dict(df3.groupby(['age']).sum()['total_sales'])

# %%
#Adding month, year, and year_month columns

df3['invoice_date'] = pd.to_datetime(df3['invoice_date'])

df3['year_month'] = df3['invoice_date'].dt.to_period('M')

# %%
#Medium #3: How is the data distributed across different invoice dates? Are there any seasonal trends or patterns? (Use a graph for this.)

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

date_count = df3['year_month'].value_counts().sort_index()

date_count.plot(kind="bar", figsize=(10, 5))

plt.xlabel("Month and Year")
plt.ylabel("Number of Orders")
plt.title("Number of Orders by Month and Year")
plt.show()

#The graph shows a significant decrease in the number of orders in 2023.

# %%
# Hard#1: Create a pivot table showing the breakdown of sales across these dimensions, in this order: category, decade age range (e.g., 10-19, 20-29, and so forth).

df3['decade_age_range'] = ((df3['age'] // 10)*10).astype(str) + "-" + (((df3['age'] // 10)*10)+9).astype(str)

pivot_table = df3.pivot_table(values='total_sales', index='category', columns='decade_age_range', aggfunc='sum')

# Plot the pivot table
pivot_table.plot(kind='bar')

# Customize the plot
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.title('Breakdown of Total Sales Across Item Categories and Decade Age Range')

# Display the plot
plt.show()

# %%
# Hard#1: Create a pivot table showing the breakdown of sales across these dimensions, in this order: category, decade age range (e.g., 10-19, 20-29, and so forth). (Without NaN values)

df_without_nan = df3.dropna()

df_without_nan['decade_age_range'] = ((df_without_nan['age'] // 10)*10).astype(str) + "-" + (((df_without_nan['age'] // 10)*10)+9).astype(str)

pivot_table = df_without_nan.pivot_table(values='total_sales', index='category', columns='decade_age_range', aggfunc='sum')

# Plot the pivot table
pivot_table.plot(kind='bar')

# Customize the plot
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.title('Breakdown of Total Sales Across Item Categories and Decade Age Range')

# Display the plot
plt.show()
# Out:
# C:\Users\megan\AppData\Local\Temp\ipykernel_16468\615545359.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_nan['decade_age_range'] = ((df_without_nan['age'] // 10)*10).astype(str) + "-" + (((df_without_nan['age'] // 10)*10)+9).astype(str)
